# %%
from PIL import Image, ImageDraw, ImageFont

from matplotlib.pyplot import imshow as plt_imshow
import numpy as np
# %matplotlib inline

# %%
# --------------------------------------------------------

# %%
import sys
from flask import Flask

sys.path.append('/Users/liangjh/Workspace/tspire-api/')

# %%
app = Flask('test')

# %%
app.config.from_object('config.default')
app.config.from_object('config.development')

# %%
from app.images import pixabay, poster
# Out:
# Loading environments: config.default, config.development

# %%
results = pixabay.search_images('Salute to America', app.config['PIXABAY_API_KEY'])

# %%
img = pixabay.download_image(results[9])

# %%
text = "By the way , I was talking about something , and you look where we have to build our military which I thank because a number of the pundits and overall fair but not too much ."
poster_img = poster.make_poster(img, app.config['POSTER_PARAMS']['Trump'], app.config['DATA_DIRECTORY'],
                               title='MILITARY', quote=text)

# %%
plt_imshow(np.asarray(poster_img))

# %%
poster.save_poster(poster_img, '/Users/liangjh/Desktop/')
# Out:
# {'guid': 'e061f7a811144087aeb5a8667b0c3167',
#  'img_file_lg': 'e061f7a811144087aeb5a8667b0c3167-lg.jpg',
#  'img_file_sm': 'e061f7a811144087aeb5a8667b0c3167-sm.jpg'}

# %%
from app.spire import spiremodel
# Out:
# Loading environments: config.default, config.development

# %%
spiremodel.sentence_topic_parse_filter("By the way , I was talking about something , and you look where we have to build our military which I thank because a number of the pundits and overall fair but not too much.", app.config['TOPIC_PARSE_RULES'], short_circuit=False)
# Out:
# [military, talking]

# %%
from app.spire import spiremodel
